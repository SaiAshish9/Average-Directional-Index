# %%
import pandas as pd

# %%
import numpy as np

# %%
b=pd.read_csv('Assignment1-data.csv')

# %%
c=pd.DataFrame(b)

# %%
c.head()
# Out:
#             Unnamed: 0  Open  High   Low  Close
# 0  2017-09-01 10:00:00  3079  3079  3072   3074
# 1  2017-09-01 10:10:00  3074  3074  3073   3074
# 2  2017-09-01 10:20:00  3074  3074  3072   3072
# 3  2017-09-01 10:30:00  3072  3073  3072   3073
# 4  2017-09-01 10:40:00  3073  3074  3072   3072

# %% [markdown]
# TR

# %%
a=c['High'].values.tolist()
d=c['Low'].values.tolist()
e=[]
for i in range(1,len(a)):
    e.append(a[i]-d[i])
test2=a[1:]
test3=c['Close'].values.tolist()
f=[]
for i in range(0,len(test2)):
    f.append(abs(test2[i]-test3[i]))
g=[]
test4=d[1:]
for i in range(0,len(test4)):
    g.append(abs(test4[i]-test3[i]))
tr=[]
for i in range(len(e)):
    tr.append(max(e[i],f[i],g[i]))
tr=[None] + tr
c['TR']=tr

# %% [markdown]
# +DM 1

# %%
high=a[1:]
low=d[1:]
dm1=[]
for i in range(0,len(high)):
    if (high[i]-high[i-1])>(low[i-1]-low[i]):
        dm1.append(max(high[i]-high[i-1],0))
    else:
        dm1.append(0)
dm1=[None]+dm1        
c['+DM 1']=dm1

# %% [markdown]
# Result

# %% [markdown]
# -DM 1

# %%
nedm1=[]
beg=0
first=a
last=d
for i in range(1,len(low)):
    if (low[i-1]-low[i])>(high[i]-high[i-1]):
        nedm1.append(max(low[i-1]-low[i],0))
    else:
        nedm1.append(0)
if (last[0]-last[1])>(first[1]-first[0]):
    beg=max(last[0]-last[1],0)
nedm1=[None,beg]+ nedm1        
c['-DM 1']=nedm1

# %% [markdown]
# TR14

# %%
tr14=[]
start=sum(tr[1:15])
tr14=[None for x in range(14)]+[start]
for i in range(15,len(tr)):
    tr14.append(tr14[i-1]-(tr14[i-1]/14)+tr[i])
c['TR14']=tr14

# %% [markdown]
# +DM14

# %%
dm14=[]

# %%
c.head(36)
# Out:
#              Unnamed: 0  Open  High   Low  Close   TR  +DM 1  -DM 1       TR14
# 0   2017-09-01 10:00:00  3079  3079  3072   3074  NaN    NaN    NaN        NaN
# 1   2017-09-01 10:10:00  3074  3074  3073   3074  1.0    0.0    0.0        NaN
# 2   2017-09-01 10:20:00  3074  3074  3072   3072  2.0    0.0    1.0        NaN
# 3   2017-09-01 10:30:00  3072  3073  3072   3073  1.0    0.0    0.0        NaN
# 4   2017-09-01 10:40:00  3073  3074  3072   3072  2.0    1.0    0.0        NaN
# 5   2017-09-01 10:50:00  3072  3074  3072   3074  2.0    0.0    0.0        NaN
